# %% [markdown]
# ## 数据探索

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('PINGAN-2018-train_demo.csv')

# %%
high_pay = data[(data['CALLSTATE']==3) & (data['Y']>0)]

# %%
high_pay
# Out:
#        TERMINALNO        TIME  TRIP_ID   LONGITUDE   LATITUDE  DIRECTION  \
# 5876            8  1481189580       19  121.624733  38.918373        225
# 25063          39  1481249100        1  114.200912  34.087807        178
# 25117          39  1481424540       10  114.192810  34.104080        188
# 25185          39  1481434260       17  114.262238  33.990036        112
# 25197          39  1481424420       23  114.192932  34.109268        176
# 25256          39  1482563760       28  114.236977  33.987148        262
# 25404          39  1482542400       36  114.135399  34.017445        255
# 25440          39  1481522280       41  114.182899  34.085140         32
# 25449          39  1481521740       41  114.208595  34.064026          0
# 25450          39  1481521680       41  114.207230  34.056526        355
# 25482          39  1481502600       46  114.194260  34.104141        104
# 25483          39  1481502540       46  114.194084  34.103634          2
# ...

# %%
high_pay.groupby(['TERMINALNO','TRIP_ID']).count()
# Out:
#                     TIME  LONGITUDE  LATITUDE  DIRECTION  HEIGHT  SPEED  \
# TERMINALNO TRIP_ID
# 8          1           5          5         5          5       5      5
#            2           6          6         6          6       6      6
#            3           5          5         5          5       5      5
#            4          48         48        48         48      48     48
#            5           1          1         1          1       1      1
#            6           9          9         9          9       9      9
#            7           8          8         8          8       8      8
#            8           2          2         2          2       2      2
#            9           3          3         3          3       3      3
#            10         49         49        49         49      49     49
#            11          6          6         6          6       6      6
#            12         24         24        24         24      24     24
# ...

# %%
data.groupby('TERMINALNO').count()
# Out:
#             TIME  TRIP_ID  LONGITUDE  LATITUDE  DIRECTION  HEIGHT  SPEED  \
# TERMINALNO
# 1            294      294        294       294        294     294    294
# 2            728      728        728       728        728     728    728
# 3            963      963        963       963        963     963    963
# 4            792      792        792       792        792     792    792
# 5            903      903        903       903        903     903    903
# 6            478      478        478       478        478     478    478
# 7           1453     1453       1453      1453       1453    1453   1453
# 8            698      698        698       698        698     698    698
# 9            317      317        317       317        317     317    317
# 10           644      644        644       644        644     644    644
# 11          1116     1116       1116      1116       1116    1116   1116
# 12           850      850        850       850        850     850    850
# ...
